# %% [markdown]
# # 2025.1209
#
# This notebook analysis Hindcast results variation among 32 samples of w0 with EKF-RNN
# generated by the following program:
# - with Geomagnetic Snapshots terms, without LOD input:
#     - `code/2025_1017_yBnLODnLDT_h34_s0-32.py`
# - with LOD input:
#     - `code/2025_1108_yByLODnLDT_h34_s0-32.py`
# - with d(LOD)/dt input:
#     - `code/2025_1205_yBnLODyLDT_h34_s0-32.py`
#
# for SPEL seminar M2 midterm presentation.
#
#
# Candidate model
# - Number of hidden units : `Drec = 34`
# - initial $\mathbf{w}_0$ : `seed = best / worst in "00000" - "11111"` (`seed = 29 "11101"` was for IGRF-14)
# - Training method : EKF-RNN
#
# `Data Period: MCM-2024 (2004.87〜2024.87)`
#
# - Hindcast experiment (Minami et al., 2020)
# `Train Period: 2004.8739 - 2018.6247 (56 points, 14 yrs )`
# `Valid Period: 2018.8749 - 2023.6254 (20 points, 5 yrs )`

# %%
import platform           # Python 3.9.16
import sys
import re

import numpy      as np   # Numpy 1.23.2
import pandas     as pd   # Pandas 2.0.3
import matplotlib as mpl  # Matplotlib 3.7.1
import seaborn    as sns  # Seaborn 0.12.2

from matplotlib.colors import BoundaryNorm
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt

np.set_printoptions(precision=5, floatmode='fixed', suppress=True)
pd.options.display.float_format = '{:.5f}'.format

# %matplotlib inline
# print(plt.rcParams.keys())
plt.rcParams.update({
    'font.size'     : 16,
    'axes.grid'     : True,
    'grid.linestyle': '--',
    'lines.linewidth': 2,
})

print(f"Python Platform: {platform.platform()}")
print(f"    Python {sys.version}")
print(f"     Numpy {np.__version__}")
print(f"    Pandas {pd.__version__}")
print(f"Matplotlib {mpl.__version__}")
print(f"   Seaborn {sns.__version__}")
# Out:
# Python Platform: macOS-15.5-arm64-arm-64bit
#     Python 3.9.22 | packaged by conda-forge | (main, Apr 14 2025, 23:36:04)
# [Clang 18.1.8 ]
#      Numpy 1.23.2
#     Pandas 2.1.4
# Matplotlib 3.7.1
#    Seaborn 0.12.2

# %%
### Configuration
mcm_load = "../data/processed/"

dt = 0.25 # Time step
# d_max = 0-4 # Order of the derivative

Drec = 34 # Dimension of the hidden layer

fS = 2018.8749 # forecast Start time
fE = 2023.6254 # forecast End   time

TS = 2014.1244 + 0.2502 # Jerk at 2015 Start time + leapfrog for SA time
TE = 2017.3739 + 0.2502 # Jerk at 2015 End   time + leapfrog for SA time
TT = 2015.6254 + 0.2502 # Jerk gap peak time      + leapfrog for SA time

IGRF_s = 29

# font size
f_large  = 32
f_medium = 24
f_small  = 18
f_tiny   = 16

sig = 2 # Scale factor for the uncertainty plot (\pm s * sigma)

# %% [markdown]
# # Define functions

# %%
def get_energy(coef_array, time_array, gnames):
    energy_array = np.zeros((len(time_array), 14), dtype=float) # n==0 is for time

    for i, epoch in enumerate(time_array):
        #- print(epoch)
        energy_array[i, 0] = epoch

        for l, target in enumerate(gnames):
            n = int(target[2:].split(",")[0])

            energy_array[i, n] += (n+1) * coef_array[l, i] * coef_array[l, i]
    
    return energy_array.T

# %%
def draw_dP(dg_memo, dg_ref, dR_memo, time_memo, gnames, unit="nT"):
    ### get dP_n(t)

    dP2 = get_energy(dg_memo - dg_ref, time_memo, gnames).T

    # diagR = np.diagonal(dR_memo, axis1=0, axis2=1).T
    dQ2 = get_energy(dR_memo, time_memo, gnames).T

    dP2 = np.delete(dP2, [0], axis=1) # n==0 is time
    dQ2 = np.delete(dQ2, [0], axis=1)
    #- print(dP2)

    dP_df = pd.DataFrame(np.sqrt(dP2), index=time_memo, columns=range(1, 14))

    #- print(dP_df)


    fig, ax = plt.subplots(1, 2, figsize=(12, 9))

    sns.heatmap(dP_df, cmap='jet', norm=LogNorm(vmin=0.01, vmax=100), ax=ax[1])
    ax[1].set_xlabel('SH degree', fontsize=f_medium)
    ax[1].set_yticks(np.arange(1.5, len(time_memo), 4), time_memo[1::4], fontsize=f_tiny)
    ax[1].grid(False)

    dP2sum = np.sum(dP2, axis=1)
    dQ2sum = np.sum(dQ2, axis=1)
    ax[0].plot(np.sqrt(dP2sum), time_memo, c='k', label=r"sqrt(dP)")
    ax[0].plot(np.sqrt(dQ2sum), time_memo, c='k', label=r"sqrt(dQ)", linestyle='dashed')

    #- print(dPend)
    dPend = np.sqrt(dP2sum[-1])
    dQend = np.sqrt(dQ2sum[-1])
    ax[0].text(dPend, time_memo[-1], f"{dPend:.1f} {unit}  ", ha='right',  va='bottom', fontsize=f_large, color='red')
    ax[0].text(dQend, time_memo[-1], f"  {dQend:.1f} {unit}", ha='left',   va='bottom', fontsize=f_small, color='blue')


    ax[0].set_xscale('log')
    ax[0].set_xticks([0.01, 0.1, 1, 10, 100, 1000, 10000])
    ax[0].set_ylim(time_memo[-1], time_memo[0])
    ax[0].set_yticks(time_memo[1::4], time_memo[1::4], fontsize=f_tiny)
    ax[0].set_ylabel('Date (year)\n',                  fontsize=f_medium)

    fig.tight_layout()

    return fig, ax

# %%
def remove_zonal_g(g_raw, gname):
    g_nonZonal = g_raw.copy()
    cols_to_drop = []
    for l, col in enumerate(gname):
        # degree n, order m
        match = re.match(r'[gh]\((\d+),(\d+)\)', col)
        if match:
            n = int(match.group(1))
            m = int(match.group(2))
            # print(f"n={n}, m={m}")
            if m == 0:
                cols_to_drop.append(l)
                # print(f"Dropping column: {col}")
    g_nonZonal = np.delete(g_nonZonal, cols_to_drop, axis=0)
    c_nonZonal = [col for i, col in enumerate(gname) if i not in cols_to_drop]
    return g_nonZonal, c_nonZonal

# %%
def if_nan_SAgenerate(SA_memo, hindcast, diff):
    CF_time = hindcast['time_memo']
    
    if np.isnan(SA_memo[0, 50]):
        if diff == 0:
            print("  --> NaN found in SA_memo, generating SA from CF series...", end="\n")
            # Generate SA from CF series using finite difference
            CF_memo = hindcast['d0g_memo'] # RNN prediction of Core field
            for i, t in enumerate(CF_time):
                if i in [0, 1, 2]:
                    # print(f"i={i} skipped")
                    continue
                SA_memo[:, i] = (CF_memo[:, i] - 2 * CF_memo[:, i-1] + CF_memo[:, i-2]) / (dt * dt)
            
        elif diff == 1:
            print("  --> NaN found in SA_memo, generating SA from SV series...", end="\n")
            # Generate SA from SV series using finite difference
            SV_memo = hindcast['d1g_memo'] # RNN prediction of SV
            for i, t in enumerate(CF_time):
                if i in [0, 1]:
                    continue
                SA_memo[:, i] = (SV_memo[:, i] - SV_memo[:, i-1]) / dt
        
        else:
            print("  --> NaN found in SA_memo, cannot generate SA from higher derivative orders.", end="\n")
            raise ValueError("SA_memo contains NaN values and cannot be generated.")
        
        return SA_memo
    else:
        return SA_memo

# %%
### plot hidden layer output ht
def plot_ht(ht_memo, time_memo, color="black", fontsize=16, fig_ax=None):

    ht_size = ht_memo[:, 0].size

    height = 2.0
    bottom = -1 * height * np.arange(ht_size)

    if fig_ax is not None:
        fig, ax = fig_ax
    else:
        fig, ax = plt.subplots(1, 1, figsize=(12, 16))

    ymin = bottom[-1] - 0.8 * height
    ymax = bottom[0]  + 0.8 * height

    for l in range(ht_size):
        ht_l = ht_memo[l, :]
        ax.plot(time_memo, ht_l + bottom[l], 
                color=color, linewidth=2.0)

    ax.grid(True)
    ax.set_yticks(bottom)
    ax.set_yticklabels([f"$h_{{{l+1}}}$" for l in range(ht_size)], fontsize=fontsize)

    ax.set_ylim(ymin, ymax)
    ax.set_xlabel("Date (year)")
    ax.set_ylabel(r"Hidden Unit Activation")

    return fig, ax

# %% [markdown]
# # yBnLODnLDT model

# %% [markdown]
# ## Load MCM model

# %%
J = 195 # Number of Gauss coefficients up to degree n=13, including zonal terms
print("J =", J)

d0g_raw = pd.read_csv  (f"{mcm_load}/coef_g.csv")  
d1g_raw = pd.read_csv(f"{mcm_load}/coef_d1g.csv")
d2g_raw = pd.read_csv(f"{mcm_load}/coef_d2g.csv")

d0g_raw.set_index('YEAR', inplace=True)
d1g_raw.set_index('YEAR', inplace=True)
d2g_raw.set_index('YEAR', inplace=True)

d0R_raw = np.load  (f"{mcm_load}/cvar_R.npy")  
d1R_raw = np.load(f"{mcm_load}/cvar_d1R.npy")
d2R_raw = np.load(f"{mcm_load}/cvar_d2R.npy")

display(d2g_raw.head())
print(d2R_raw[0:5,0:5, 0])
print(d2R_raw[0:5,0:5, 1])
print(d2R_raw[0:5,0:5, 2])
print(d2R_raw[0:5,0:5, 3])
print(d2R_raw[0:5,0:5, -1])
# Out:
# J = 195
#              g(1,0)  g(1,1)   h(1,1)   g(2,0)   g(2,1)   h(2,1)  g(2,2)  \
# YEAR
# 2004.87390      NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 2005.12370      NaN     NaN      NaN      NaN      NaN      NaN     NaN
# 2005.37390 -1.30880 2.22560 -0.89280 -0.17440 -0.08800 -0.74240 1.53120
# 2005.62410 -0.00000 1.10080 -0.70560  0.47520 -0.55680 -0.27360 1.43360
# 2005.87420 -0.78560 1.80640 -1.30880  0.81440 -0.77440 -0.56000 2.16160
#
#             h(2,2)   g(3,0)   g(3,1)  ...  g(18,14)  h(18,14)  g(18,15)  \
# YEAR                                  ...
# 2004.87390     NaN      NaN      NaN  ...       NaN       NaN       NaN
# 2005.12370     NaN      NaN      NaN  ...       NaN       NaN       NaN
# 2005.37390 0.15680 -0.06880  0.20320  ...  -0.00160  -0.00000  -0.00000
# 2005.62410 0.30720 -0.10240 -0.53280  ...   0.00160   0.00000   0.00000
# 2005.87420 1.32000  0.09280  0.14880  ...  -0.00160  -0.00000  -0.00160
#
#             h(18,15)  g(18,16)  h(18,16)  g(18,17)  h(18,17)  g(18,18)  \
# YEAR
# 2004.87390       NaN       NaN       NaN       NaN       NaN       NaN
# 2005.12370       NaN       NaN       NaN       NaN       NaN       NaN
# 2005.37390  -0.00000   0.00160   0.00000   0.00160   0.00000   0.00160
# 2005.62410   0.00000  -0.00160  -0.00000  -0.00160  -0.00160  -0.00160
# 2005.87420  -0.00160   0.00000   0.00160   0.00000   0.00160   0.00000
#
#             h(18,18)
# YEAR
# 2004.87390       NaN
# 2005.12370       NaN
# 2005.37390  -0.00160
# 2005.62410   0.00160
# 2005.87420  -0.00000
#
# [5 rows x 360 columns]
# [[2004.87400        nan        nan        nan        nan]
#  [       nan        nan        nan        nan        nan]
#  [       nan        nan        nan        nan        nan]
#  [       nan        nan        nan        nan        nan]
#  [       nan        nan        nan        nan        nan]]
# [[2005.12400        nan        nan        nan        nan]
#  [       nan        nan        nan        nan        nan]
#  [       nan        nan        nan        nan        nan]
#  [       nan        nan        nan        nan        nan]
#  [       nan        nan        nan        nan        nan]]
# [[2005.37400        nan        nan        nan        nan]
#  [       nan   36.30865   -0.34635   -0.11209    1.66008]
#  [       nan   -0.34635   20.52914   -0.11124   -0.04573]
#  [       nan   -0.11209   -0.11124   25.27605    0.14777]
#  [       nan    1.66008   -0.04573    0.14777   18.48007]]
# [[2005.62400        nan        nan        nan        nan]
#  [       nan   36.29873   -0.34612   -0.11215    1.66007]
#  [       nan   -0.34612   20.52360   -0.11082   -0.04672]
#  [       nan   -0.11215   -0.11082   25.26924    0.14846]
#  [       nan    1.66007   -0.04672    0.14846   18.47446]]
# [[2024.62400        nan        nan        nan        nan]
#  [       nan   83.50674   -0.27826   -0.16526    1.55067]
#  [       nan   -0.27826   39.74937    0.02322   -0.01262]
#  [       nan   -0.16526    0.02322   50.71966    0.17816]
#  [       nan    1.55067   -0.01262    0.17816   37.66672]]

# %%
coef_raw    = [d0g_raw.iloc[:, :J], d1g_raw.iloc[:, :J], d2g_raw.iloc[:, :J]]
Rmatrix_raw = [d0R_raw[:J+1, :J+1, :], d1R_raw[:J+1, :J+1, :], d2R_raw[:J+1, :J+1, :]]

col_raw = coef_raw[0].columns.tolist()
time_raw = coef_raw[0].index.values

print(col_raw)
print(time_raw)
print(d0R_raw[0, 0, :])
# Out:
# ['g(1,0)', 'g(1,1)', 'h(1,1)', 'g(2,0)', 'g(2,1)', 'h(2,1)', 'g(2,2)', 'h(2,2)', 'g(3,0)', 'g(3,1)', 'h(3,1)', 'g(3,2)', 'h(3,2)', 'g(3,3)', 'h(3,3)', 'g(4,0)', 'g(4,1)', 'h(4,1)', 'g(4,2)', 'h(4,2)', 'g(4,3)', 'h(4,3)', 'g(4,4)', 'h(4,4)', 'g(5,0)', 'g(5,1)', 'h(5,1)', 'g(5,2)', 'h(5,2)', 'g(5,3)', 'h(5,3)', 'g(5,4)', 'h(5,4)', 'g(5,5)', 'h(5,5)', 'g(6,0)', 'g(6,1)', 'h(6,1)', 'g(6,2)', 'h(6,2)', 'g(6,3)', 'h(6,3)', 'g(6,4)', 'h(6,4)', 'g(6,5)', 'h(6,5)', 'g(6,6)', 'h(6,6)', 'g(7,0)', 'g(7,1)', 'h(7,1)', 'g(7,2)', 'h(7,2)', 'g(7,3)', 'h(7,3)', 'g(7,4)', 'h(7,4)', 'g(7,5)', 'h(7,5)', 'g(7,6)', 'h(7,6)', 'g(7,7)', 'h(7,7)', 'g(8,0)', 'g(8,1)', 'h(8,1)', 'g(8,2)', 'h(8,2)', 'g(8,3)', 'h(8,3)', 'g(8,4)', 'h(8,4)', 'g(8,5)', 'h(8,5)', 'g(8,6)', 'h(8,6)', 'g(8,7)', 'h(8,7)', 'g(8,8)', 'h(8,8)', 'g(9,0)', 'g(9,1)', 'h(9,1)', 'g(9,2)', 'h(9,2)', 'g(9,3)', 'h(9,3)', 'g(9,4)', 'h(9,4)', 'g(9,5)', 'h(9,5)', 'g(9,6)', 'h(9,6)', 'g(9,7)', 'h(9,7)', 'g(9,8)', 'h(9,8)', 'g(9,9)', 'h(9,9)', 'g(10,0)', 'g(10,1)', 'h(10,1)', 'g(10,2)', 'h(10,2)', 'g(10,3)', 'h(10,3)', 'g(10,4)', 'h(10,4)', 'g(10,5)', 'h(10,5)', 'g(10,6)', 'h(10,6)', 'g(10,7)', 'h(10,7)', 'g(10,8)', 'h(10,8)', 'g(10,9)', 'h(10,9)', 'g(10,10)', 'h(10,10)', 'g(11,0)', 'g(11,1)', 'h(11,1)', 'g(11,2)', 'h(11,2)', 'g(11,3)', 'h(11,3)', 'g(11,4)', 'h(11,4)', 'g(11,5)', 'h(11,5)', 'g(11,6)', 'h(11,6)', 'g(11,7)', 'h(11,7)', 'g(11,8)', 'h(11,8)', 'g(11,9)', 'h(11,9)', 'g(11,10)', 'h(11,10)', 'g(11,11)', 'h(11,11)', 'g(12,0)', 'g(12,1)', 'h(12,1)', 'g(12,2)', 'h(12,2)', 'g(12,3)', 'h(12,3)', 'g(12,4)', 'h(12,4)', 'g(12,5)', 'h(12,5)', 'g(12,6)', 'h(12,6)', 'g(12,7)', 'h(12,7)', 'g(12,8)', 'h(12,8)', 'g(12,9)', 'h(12,9)', 'g(12,10)', 'h(12,10)', 'g(12,11)', 'h(12,11)', 'g(12,12)', 'h(12,12)', 'g(13,0)', 'g(13,1)', 'h(13,1)', 'g(13,2)', 'h(13,2)', 'g(13,3)', 'h(13,3)', 'g(13,4)', 'h(13,4)', 'g(13,5)', 'h(13,5)', 'g(13,6)', 'h(13,6)', 'g(13,7)', 'h(13,7)', 'g(13,8)', 'h(13,8)', 'g(13,9)', 'h(13,9)', 'g(13,10)', 'h(13,10)', 'g(13,11)', 'h(13,11)', 'g(13,12)', 'h(13,12)', 'g(13,13)', 'h(13,13)']
# [2004.87390 2005.12370 2005.37390 2005.62410 2005.87420 2006.12440
#  2006.37460 2006.62470 2006.87490 2007.12510 2007.37530 2007.62540
#  2007.87560 2008.12540 2008.37490 2008.62440 2008.87390 2009.12370
#  2009.37390 2009.62410 2009.87420 2010.12440 2010.37460 2010.62470
#  2010.87490 2011.12510 2011.37530 2011.62540 2011.87560 2012.12540
#  2012.37490 2012.62440 2012.87390 2013.12370 2013.37390 2013.62410
#  2013.87420 2014.12440 2014.37460 2014.62470 2014.87490 2015.12510
#  2015.37530 2015.62540 2015.87560 2016.12540 2016.37490 2016.62440
#  2016.87390 2017.12370 2017.37390 2017.62410 2017.87420 2018.12440
#  2018.37460 2018.62470 2018.87490 2019.12510 2019.37530 2019.62540
#  2019.87560 2020.12540 2020.37490 2020.62440 2020.87390 2021.12370
#  2021.37390 2021.62410 2021.87420 2022.12440 2022.37460 2022.62470
#  2022.87490 2023.12510 2023.37530 2023.62540 2023.87560 2024.12540
#  2024.37490 2024.62440 2024.87390 2025.12370 2025.37390 2025.62410
#  2025.87420 2026.12440 2026.37460 2026.62470 2026.87490 2027.12510
#  2027.37530 2027.62540 2027.87560 2028.12540 2028.37490 2028.62440
#  2028.87390 2029.12370 2029.37390 2029.62410 2029.87420 2030.12440
#  2030.37460 2030.62470 2030.87490]
# [2004.87400 2005.12400 2005.37400 2005.62400 2005.87400 2006.12400
#  2006.37500 2006.62500 2006.87500 2007.12500 2007.37500 2007.62500
#  2007.87600 2008.12500 2008.37500 2008.62400 2008.87400 2009.12400
#  2009.37400 2009.62400 2009.87400 2010.12400 2010.37500 2010.62500
#  2010.87500 2011.12500 2011.37500 2011.62500 2011.87600 2012.12500
#  2012.37500 2012.62400 2012.87400 2013.12400 2013.37400 2013.62400
#  2013.87400 2014.12400 2014.37500 2014.62500 2014.87500 2015.12500
#  2015.37500 2015.62500 2015.87600 2016.12500 2016.37500 2016.62400
#  2016.87400 2017.12400 2017.37400 2017.62400 2017.87400 2018.12400
#  2018.37500 2018.62500 2018.87500 2019.12500 2019.37500 2019.62500
#  2019.87600 2020.12500 2020.37500 2020.62400 2020.87400 2021.12400
#  2021.37400 2021.62400 2021.87400 2022.12400 2022.37500 2022.62500
#  2022.87500 2023.12500 2023.37500 2023.62500 2023.87600 2024.12500
#  2024.37500 2024.62400]

# %%
print(TT)
TT_idx = np.abs(time_raw - TT).argmin()
TT = time_raw[TT_idx]

print(f"target_epoch = {TT}")
CF_ref = coef_raw[0].loc[TT, :].values.T # Reference CF at target_epoch
SV_ref = coef_raw[1].loc[TT, :].values.T # Reference SV at target_epoch
SA_ref = coef_raw[2].loc[TT, :].values.T # Reference SA at target_epoch
TG_ref = SA_ref.reshape(-1, 1) # target field
print(TG_ref.shape, "\n", TG_ref[:5])
# Out:
# 2015.8755999999998
# target_epoch = 2015.8756
# (195, 1)
#  [[-1.30720]
#  [-4.02880]
#  [-2.77600]
#  [ 0.51520]
#  [-1.68960]]

# %% [markdown]
# ### Geomagnetic Snapshots only (MCM-RNN)

# %%
MCM_SAddP = pd.DataFrame(index=np.arange(0, 5), columns=np.arange(0, 32), dtype=float)
save_dir = "../output/2025_1017_yBnLODnLDT_h34_s0-32"

for d_max in range(5):
    for seed in range(0, 32):
        b_seed = format(seed, '05b') # seed No. as 5-bit binary

        filename = f"d{d_max}g_{Drec}_{b_seed}_geomag_memos.npz"

        read_file = f"{save_dir}/{filename}"

        print(f"reading {(d_max, Drec, b_seed)}: ", end="")

        pred_memos = np.load(read_file, allow_pickle=True)
        print(f"loaded --> ", end="\n")
        
        CF_time = pred_memos['time_memo']   # time - leap frog
        CF_cols = pred_memos['columns'][:J] # target field columns
        SA_memo = pred_memos['d2g_memo'] # RNN prediction of SA

        SA_memo = if_nan_SAgenerate(SA_memo, pred_memos, diff=d_max)

        TG_memo = SA_memo[:J, :] # target field

        print(f"time={CF_time.shape}, shape={TG_memo.shape} --> ", end="")

        # t_idx = np.where(CF_time == target_epoch)[0][0]
        # print(f"t_idx={fE_idx} --> ", end="")

        # 範囲インデックス配列の作成
        # tS_idx = np.abs(CF_time - TS).argmin()
        # tE_idx = np.abs(CF_time - TE).argmin()
        # t_indices = np.arange(tS_idx, tE_idx + 1)
        
        t_idx = np.abs(CF_time - TT).argmin()
        t_indices = [t_idx]
        print(f"t_indices from {t_indices[0]} to {t_indices[-1]} ({len(t_indices)} points) --> ", end="")

        TG_rnn = TG_memo[:, t_indices] # multiple time steps
        error = TG_rnn - TG_ref
        print("error.shape: ", error.shape, len(CF_cols), "--> ", end="")
        
        ddP2 = get_energy(error, CF_time[t_indices], CF_cols)
        # print("ddP2:", ddP2)
        print("ddP2.shape", ddP2.shape, len(CF_cols), "--> ", end="")
        #sqrtddP = np.sqrt(np.trapz(ddP2[1:, :].sum(axis=0), CF_time[t_indices])) # integrate over time
        sqrtddP = np.sqrt(ddP2[1:, :].sum())

        print(f"sqrt(ddP)={sqrtddP:.4f} nT --> ", end="")
        MCM_SAddP.loc[d_max, seed] = sqrtddP

        print("ddP table done", end="\n")
# Out:
# reading (0, 34, '00000'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00001'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00010'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00011'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00100'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00101'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00110'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00111'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01000'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01001'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01010'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01011'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01100'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01101'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01110'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01111'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10000'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10001'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10010'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10011'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10100'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10101'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10110'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10111'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11000'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11001'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11010'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11011'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11100'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11101'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11110'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11111'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (1, 34, '00000'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=11.3759 nT --> ddP table done
# reading (1, 34, '00001'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=90.8001 nT --> ddP table done
# reading (1, 34, '00010'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=12.7870 nT --> ddP table done
# reading (1, 34, '00011'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.0546 nT --> ddP table done
# reading (1, 34, '00100'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=7.6150 nT --> ddP table done
# reading (1, 34, '00101'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.2620 nT --> ddP table done
# reading (1, 34, '00110'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.4895 nT --> ddP table done
# reading (1, 34, '00111'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.6927 nT --> ddP table done
# reading (1, 34, '01000'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.6424 nT --> ddP table done
# reading (1, 34, '01001'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.5312 nT --> ddP table done
# reading (1, 34, '01010'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=5.3485 nT --> ddP table done
# reading (1, 34, '01011'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.5274 nT --> ddP table done
# reading (1, 34, '01100'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.6409 nT --> ddP table done
# reading (1, 34, '01101'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=5.9918 nT --> ddP table done
# reading (1, 34, '01110'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=5.8639 nT --> ddP table done
# reading (1, 34, '01111'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.6748 nT --> ddP table done
# reading (1, 34, '10000'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=22.5834 nT --> ddP table done
# reading (1, 34, '10001'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.6927 nT --> ddP table done
# reading (1, 34, '10010'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=7.5661 nT --> ddP table done
# reading (1, 34, '10011'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.1816 nT --> ddP table done
# reading (1, 34, '10100'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.7349 nT --> ddP table done
# reading (1, 34, '10101'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3425 nT --> ddP table done
# reading (1, 34, '10110'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=27.1163 nT --> ddP table done
# reading (1, 34, '10111'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=31.9189 nT --> ddP table done
# reading (1, 34, '11000'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=0.2151 nT --> ddP table done
# reading (1, 34, '11001'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=0.8964 nT --> ddP table done
# reading (1, 34, '11010'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.6409 nT --> ddP table done
# reading (1, 34, '11011'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=11.5627 nT --> ddP table done
# reading (1, 34, '11100'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=145.3719 nT --> ddP table done
# reading (1, 34, '11101'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.5274 nT --> ddP table done
# reading (1, 34, '11110'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.6424 nT --> ddP table done
# reading (1, 34, '11111'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.5312 nT --> ddP table done
# reading (2, 34, '00000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.7298 nT --> ddP table done
# reading (2, 34, '00001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=1.7935 nT --> ddP table done
# reading (2, 34, '00010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.8201 nT --> ddP table done
# reading (2, 34, '00011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.1058 nT --> ddP table done
# reading (2, 34, '00100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.2038 nT --> ddP table done
# reading (2, 34, '00101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.7198 nT --> ddP table done
# reading (2, 34, '00110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.5803 nT --> ddP table done
# reading (2, 34, '00111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.8901 nT --> ddP table done
# reading (2, 34, '01000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.4652 nT --> ddP table done
# reading (2, 34, '01001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.3126 nT --> ddP table done
# reading (2, 34, '01010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.6992 nT --> ddP table done
# reading (2, 34, '01011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.5728 nT --> ddP table done
# reading (2, 34, '01100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.4598 nT --> ddP table done
# reading (2, 34, '01101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.2860 nT --> ddP table done
# reading (2, 34, '01110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.6904 nT --> ddP table done
# reading (2, 34, '01111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.3854 nT --> ddP table done
# reading (2, 34, '10000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.2365 nT --> ddP table done
# reading (2, 34, '10001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.4474 nT --> ddP table done
# reading (2, 34, '10010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.4780 nT --> ddP table done
# reading (2, 34, '10011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.2275 nT --> ddP table done
# reading (2, 34, '10100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.1064 nT --> ddP table done
# reading (2, 34, '10101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.3756 nT --> ddP table done
# reading (2, 34, '10110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.5224 nT --> ddP table done
# reading (2, 34, '10111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.2556 nT --> ddP table done
# reading (2, 34, '11000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.6297 nT --> ddP table done
# reading (2, 34, '11001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.8128 nT --> ddP table done
# reading (2, 34, '11010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.9821 nT --> ddP table done
# reading (2, 34, '11011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.7044 nT --> ddP table done
# reading (2, 34, '11100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=5.0587 nT --> ddP table done
# reading (2, 34, '11101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.9822 nT --> ddP table done
# reading (2, 34, '11110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.4601 nT --> ddP table done
# reading (2, 34, '11111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9828 nT --> ddP table done
# reading (3, 34, '00000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.6034 nT --> ddP table done
# reading (3, 34, '00001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9087 nT --> ddP table done
# reading (3, 34, '00010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9204 nT --> ddP table done
# reading (3, 34, '00011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.6049 nT --> ddP table done
# reading (3, 34, '00100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.8746 nT --> ddP table done
# reading (3, 34, '00101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.0081 nT --> ddP table done
# reading (3, 34, '00110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.3058 nT --> ddP table done
# reading (3, 34, '00111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.7547 nT --> ddP table done
# reading (3, 34, '01000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.1005 nT --> ddP table done
# reading (3, 34, '01001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.1134 nT --> ddP table done
# reading (3, 34, '01010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.1964 nT --> ddP table done
# reading (3, 34, '01011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.6572 nT --> ddP table done
# reading (3, 34, '01100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9357 nT --> ddP table done
# reading (3, 34, '01101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9056 nT --> ddP table done
# reading (3, 34, '01110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9400 nT --> ddP table done
# reading (3, 34, '01111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.0778 nT --> ddP table done
# reading (3, 34, '10000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.3605 nT --> ddP table done
# reading (3, 34, '10001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.3294 nT --> ddP table done
# reading (3, 34, '10010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.0097 nT --> ddP table done
# reading (3, 34, '10011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.5800 nT --> ddP table done
# reading (3, 34, '10100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.3114 nT --> ddP table done
# reading (3, 34, '10101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9031 nT --> ddP table done
# reading (3, 34, '10110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.6779 nT --> ddP table done
# reading (3, 34, '10111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.1899 nT --> ddP table done
# reading (3, 34, '11000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.1547 nT --> ddP table done
# reading (3, 34, '11001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.1490 nT --> ddP table done
# reading (3, 34, '11010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.1203 nT --> ddP table done
# reading (3, 34, '11011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.3265 nT --> ddP table done
# reading (3, 34, '11100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9741 nT --> ddP table done
# reading (3, 34, '11101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.1890 nT --> ddP table done
# reading (3, 34, '11110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.8373 nT --> ddP table done
# reading (3, 34, '11111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.2134 nT --> ddP table done
# reading (4, 34, '00000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.3559 nT --> ddP table done
# reading (4, 34, '00001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2773 nT --> ddP table done
# reading (4, 34, '00010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1954 nT --> ddP table done
# reading (4, 34, '00011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1009 nT --> ddP table done
# reading (4, 34, '00100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1323 nT --> ddP table done
# reading (4, 34, '00101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1604 nT --> ddP table done
# reading (4, 34, '00110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1042 nT --> ddP table done
# reading (4, 34, '00111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2116 nT --> ddP table done
# reading (4, 34, '01000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2301 nT --> ddP table done
# reading (4, 34, '01001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0610 nT --> ddP table done
# reading (4, 34, '01010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0969 nT --> ddP table done
# reading (4, 34, '01011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0817 nT --> ddP table done
# reading (4, 34, '01100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2842 nT --> ddP table done
# reading (4, 34, '01101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.3261 nT --> ddP table done
# reading (4, 34, '01110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2208 nT --> ddP table done
# reading (4, 34, '01111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.8753 nT --> ddP table done
# reading (4, 34, '10000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0753 nT --> ddP table done
# reading (4, 34, '10001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2225 nT --> ddP table done
# reading (4, 34, '10010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.9730 nT --> ddP table done
# reading (4, 34, '10011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2777 nT --> ddP table done
# reading (4, 34, '10100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1990 nT --> ddP table done
# reading (4, 34, '10101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1837 nT --> ddP table done
# reading (4, 34, '10110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2959 nT --> ddP table done
# reading (4, 34, '10111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1292 nT --> ddP table done
# reading (4, 34, '11000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.3426 nT --> ddP table done
# reading (4, 34, '11001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0754 nT --> ddP table done
# reading (4, 34, '11010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.3422 nT --> ddP table done
# reading (4, 34, '11011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2822 nT --> ddP table done
# reading (4, 34, '11100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.4148 nT --> ddP table done
# reading (4, 34, '11101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1264 nT --> ddP table done
# reading (4, 34, '11110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1553 nT --> ddP table done
# reading (4, 34, '11111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.3240 nT --> ddP table done

# %%
display(MCM_SAddP.T)
display(MCM_SAddP.T.describe())
# Out:
#          0         1       2       3        4
# 0  9.37341  11.37588 3.72983 2.60338 10.35589
# 1  9.37341  90.80010 1.79349 2.90875 10.27732
# 2  9.37341  12.78696 2.82009 2.92037 10.19538
# 3  9.37341   2.05463 4.10582 3.60493 10.10093
# 4  9.37341   7.61503 3.20381 2.87456 10.13234
# 5  9.37341   3.26200 3.71982 3.00812 10.16038
# 6  9.37341   2.48949 4.58034 3.30582 10.10422
# 7  9.37341   9.69273 3.89015 2.75472 10.21156
# 8  9.37341   9.64242 4.46521 3.10045 10.23009
# 9  9.37341   9.53117 3.31259 3.11336 10.06104
# 10 9.37341   5.34849 3.69922 3.19640 10.09688
# 11 9.37341   9.52742 3.57276 2.65724 10.08171
# 12 9.37341   9.64090 3.45977 2.93569 10.28422
# 13 9.37341   5.99182 2.28598 2.90563 10.32607
# 14 9.37341   5.86393 2.69036 2.94004 10.22077
# 15 9.37341   3.67478 3.38541 3.07783  9.87526
# 16 9.37341  22.58340 3.23650 3.36053 10.07531
# 17 9.37341   9.69273 3.44737 3.32943 10.22246
# 18 9.37341   7.56606 3.47797 3.00975  9.97303
# 19 9.37341   4.18155 3.22746 3.58001 10.27771
# 20 9.37341   2.73488 4.10642 3.31143 10.19904
# 21 9.37341   9.34245 3.37558 2.90310 10.18369
# 22 9.37341  27.11632 3.52239 2.67795 10.29593
# 23 9.37341  31.91888 3.25562 3.18992 10.12921
# 24 9.37341   0.21513 2.62969 3.15468 10.34259
# 25 9.37341   0.89639 2.81279 3.14899 10.07538
# 26 9.37341   9.64090 4.98213 4.12030 10.34217
# 27 9.37341  11.56266 2.70444 3.32651 10.28222
# 28 9.37341 145.37193 5.05873 2.97410 10.41479
# 29 9.37341   9.52742 4.98219 3.18898 10.12639
# 30 9.37341   9.64242 3.46010 2.83732 10.15529
# 31 9.37341   9.53117 2.98280 3.21338 10.32404
#              0         1        2        3        4
# count 32.00000  32.00000 32.00000 32.00000 32.00000
# mean   9.37341  15.96319  3.49928  3.10105 10.19167
# std    0.00000  28.51078  0.76096  0.30689  0.12007
# min    9.37341   0.21513  1.79349  2.60338  9.87526
# 25%    9.37341   5.05675  3.14856  2.90797 10.10340
# 50%    9.37341   9.52930  3.45357  3.08914 10.19721
# 75%    9.37341  10.11352  3.76991  3.23649 10.28272
# max    9.37341 145.37193  5.05873  4.12030 10.41479

# %%
# plot SA Energy series for s=29
plot_table = MCM_SAddP

for diff in [0, 1, 2]:

    fig, ax = plt.subplots(1, 1, figsize=(12, 9))

    cmap = mpl.colormaps['cool']
    norm = BoundaryNorm(plot_table.columns, cmap.N)
    seed_l = plot_table.columns[0:31:2]

    for s in [29]:
        b_seed = format(s, '05b')
        hindcast = np.load(f"{save_dir}/d{diff}g_{Drec}_{b_seed}_geomag_memos.npz", allow_pickle=True)

        SA_time = hindcast['time_memo'] - 0.2502  # adjust time for SA leapfrog
        SA_memo = hindcast['d2g_memo'] # RNN prediction of SA

        SA_memo = if_nan_SAgenerate(SA_memo, hindcast, diff=diff)

        SA_Energy_col = get_energy(SA_memo[:J, :], SA_time, hindcast['columns'][:J])
        SA_Energy_tot = SA_Energy_col[1:, :].sum(axis=0)

        # print(SA_Energy_col[0, :], SA_Energy_tot)

        ax.plot(SA_Energy_col[0, :], SA_Energy_tot, 
                c=cmap(norm(s)), alpha=0.7)


    SA_ref = coef_raw[2].loc[hindcast['time_memo'], :].values.T # Reference SA time series
    SA_Energy_ref_col = get_energy(SA_ref, hindcast['time_memo'] - 0.2502, hindcast['columns'][:J])
    SA_Energy_ref_tot = SA_Energy_ref_col[1:, :].sum(axis=0)
    ax.plot(SA_Energy_ref_col[0, :], SA_Energy_ref_tot, c='black', label='MCM-2024')


    p = ax.scatter([np.nan]*32, [np.nan]*32, cmap=cmap, norm=norm, c=range(32), alpha=1.0, marker='none')
    ax.colorbar = plt.colorbar(p, ax=ax)
    ax.colorbar.set_label(r"Random Seed  $s$", fontsize=f_large)
    # print([f"{seed} ({format(seed, '05b')})" for seed in seed_l])
    ax.colorbar.set_ticks                                                    (seed_l)
    ax.colorbar.set_ticklabels([f"{seed} ({format(seed, '05b')})" for seed in seed_l])


    ymin, ymax = 0, 200
    ax.set_ylim(ymin, ymax)

    ax.fill_between(hindcast['time_memo'], ymin, ymax, 
                    where=(hindcast['time_memo']>=fS) & (hindcast['time_memo']<=fE), 
                    color='yellow', alpha=0.5, label=f'Hindcast period ({fS:.2f} - {fE:.2f})')
    ax.fill_between(hindcast['time_memo'], ymin, ymax, 
                    where=(hindcast['time_memo']>=TS-0.2502) & (hindcast['time_memo']<=TE-0.2502), 
                    color='orange', alpha=0.5, label=f'2015 Pulse ({TS-0.25:.2f} - {TE-0.25:.2f})')

    ax.set_xlabel('Date (year)', fontsize=f_large)
    ax.set_ylabel(r"SA Energy  (nT/yr$^2$)$^2$", fontsize=f_large)
    ax.set_title(r"SA Energy  (nT/yr$^2$)$^2$   (Trained with Gauss coefs.)" + 
                f"\n Derivative d={diff} | Seed s=11101 | Drec=34" + 
                f"\n Error/Misfit time: {TS-0.2502:.4f} ≦ t ≦ {TE-0.2502:.4f} \n", 
                fontsize=f_large)
    ax.legend(fontsize=f_large)
    plt.tight_layout()
    plt.show()
# Out:
#   --> NaN found in SA_memo, generating SA from CF series...
#   --> NaN found in SA_memo, generating SA from SV series...

# %% [markdown]
# ### B + LOD data (LOD-RNN)

# %%
### Compute ddP table
LOD_SAddP = pd.DataFrame(index=np.arange(0, 5), columns=np.arange(0, 32), dtype=float)

save_dir = "../output/2025_1108_yByLODnLDT_h34_s0-32"
for d_max in range(5):
    for seed in range(0, 32):
        b_seed = format(seed, '05b') # seed No. as 5-bit binary

        filename = f"d{d_max}g_{Drec}_{b_seed}_geomag_memos.npz"

        read_file = f"{save_dir}/{filename}"

        print(f"reading {(d_max, Drec, b_seed)}: ", end="")

        try:
            pred_memos = np.load(read_file, allow_pickle=True)
        except Exception as e:
            print(f"Error loading {read_file}: {e}")
            continue
        
        print(f"loaded --> ", end="\n")
        
        CF_time = pred_memos['time_memo']       # time - leap frog
        CF_cols = pred_memos['columns'][:J]   # target field columns, exclude LOD at the end
        SA_memo = pred_memos['d2g_memo']        # RNN prediction of SA

        SA_memo = if_nan_SAgenerate(SA_memo, pred_memos, diff=d_max)

        TG_memo = SA_memo[:J, :] # target field (exclude LOD at the end)

        print(f"time={CF_time.shape}, shape={TG_memo.shape} --> ", end="")

        # t_idx = np.where(CF_time == target_epoch)[0][0]
        # print(f"t_idx={fE_idx} --> ", end="")

        # 範囲インデックス配列の作成
        # tS_idx = np.abs(CF_time - TS).argmin()
        # tE_idx = np.abs(CF_time - TE).argmin()
        # t_indices = np.arange(tS_idx, tE_idx + 1)

        t_idx = np.abs(CF_time - TT).argmin()
        t_indices = [t_idx]
        print(f"t_indices from {t_indices[0]} to {t_indices[-1]} ({len(t_indices)} points) --> ", end="")

        TG_rnn = TG_memo[:, t_indices] # multiple time steps
        error  = TG_rnn - TG_ref
        print("error.shape: ", error.shape, len(CF_cols), "--> ", end="")
        
        ddP2 = get_energy(error, CF_time[t_indices], CF_cols)
        # print("ddP2:", ddP2)
        print("ddP2.shape", ddP2.shape, len(CF_cols), "--> ", end="")
        # sqrtddP = np.sqrt(np.trapz(ddP2[1:, :].sum(axis=0), CF_time[t_indices])) # integrate over time
        sqrtddP = np.sqrt(ddP2[1:, :].sum()) # integrate over time

        print(f"sqrt(ddP)={sqrtddP:.4f} nT --> ", end="")
        LOD_SAddP.loc[d_max, seed] = sqrtddP

        print("ddP table done", end="\n")
# Out:
# reading (0, 34, '00000'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00001'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00010'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00011'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00100'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00101'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00110'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '00111'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01000'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01001'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01010'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01011'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01100'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01101'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01110'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '01111'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10000'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10001'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10010'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10011'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10100'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10101'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10110'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '10111'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11000'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11001'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11010'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11011'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11100'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11101'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11110'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11111'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (1, 34, '00000'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=0.1705 nT --> ddP table done
# reading (1, 34, '00001'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=35.1707 nT --> ddP table done
# reading (1, 34, '00010'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1892 nT --> ddP table done
# reading (1, 34, '00011'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=5.8118 nT --> ddP table done
# reading (1, 34, '00100'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.2581 nT --> ddP table done
# reading (1, 34, '00101'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.5826 nT --> ddP table done
# reading (1, 34, '00110'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=247.8158 nT --> ddP table done
# reading (1, 34, '00111'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.6927 nT --> ddP table done
# reading (1, 34, '01000'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.2193 nT --> ddP table done
# reading (1, 34, '01001'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=22.6796 nT --> ddP table done
# reading (1, 34, '01010'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=1.2898 nT --> ddP table done
# reading (1, 34, '01011'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.5200 nT --> ddP table done
# reading (1, 34, '01100'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=11.6449 nT --> ddP table done
# reading (1, 34, '01101'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=14.4305 nT --> ddP table done
# reading (1, 34, '01110'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.6900 nT --> ddP table done
# reading (1, 34, '01111'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=7.1392 nT --> ddP table done
# reading (1, 34, '10000'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=68.2411 nT --> ddP table done
# reading (1, 34, '10001'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.6927 nT --> ddP table done
# reading (1, 34, '10010'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=17.4592 nT --> ddP table done
# reading (1, 34, '10011'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=16.0029 nT --> ddP table done
# reading (1, 34, '10100'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=11.0301 nT --> ddP table done
# reading (1, 34, '10101'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=59.0445 nT --> ddP table done
# reading (1, 34, '10110'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=1.9254 nT --> ddP table done
# reading (1, 34, '10111'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.8804 nT --> ddP table done
# reading (1, 34, '11000'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.6900 nT --> ddP table done
# reading (1, 34, '11001'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=7.1525 nT --> ddP table done
# reading (1, 34, '11010'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=83.1841 nT --> ddP table done
# reading (1, 34, '11011'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.4994 nT --> ddP table done
# reading (1, 34, '11100'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=26.5707 nT --> ddP table done
# reading (1, 34, '11101'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.5200 nT --> ddP table done
# reading (1, 34, '11110'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.4017 nT --> ddP table done
# reading (1, 34, '11111'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=6.2368 nT --> ddP table done
# reading (2, 34, '00000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9418 nT --> ddP table done
# reading (2, 34, '00001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.0714 nT --> ddP table done
# reading (2, 34, '00010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.0476 nT --> ddP table done
# reading (2, 34, '00011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.1316 nT --> ddP table done
# reading (2, 34, '00100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.5121 nT --> ddP table done
# reading (2, 34, '00101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.1935 nT --> ddP table done
# reading (2, 34, '00110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=5.6216 nT --> ddP table done
# reading (2, 34, '00111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=5.3660 nT --> ddP table done
# reading (2, 34, '01000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.8099 nT --> ddP table done
# reading (2, 34, '01001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.7529 nT --> ddP table done
# reading (2, 34, '01010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.0762 nT --> ddP table done
# reading (2, 34, '01011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.2340 nT --> ddP table done
# reading (2, 34, '01100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=5.4067 nT --> ddP table done
# reading (2, 34, '01101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.8538 nT --> ddP table done
# reading (2, 34, '01110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.5816 nT --> ddP table done
# reading (2, 34, '01111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.6762 nT --> ddP table done
# reading (2, 34, '10000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.5739 nT --> ddP table done
# reading (2, 34, '10001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.7947 nT --> ddP table done
# reading (2, 34, '10010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.3497 nT --> ddP table done
# reading (2, 34, '10011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.8641 nT --> ddP table done
# reading (2, 34, '10100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=1.9958 nT --> ddP table done
# reading (2, 34, '10101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.2868 nT --> ddP table done
# reading (2, 34, '10110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.3785 nT --> ddP table done
# reading (2, 34, '10111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.6650 nT --> ddP table done
# reading (2, 34, '11000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.5711 nT --> ddP table done
# reading (2, 34, '11001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.7990 nT --> ddP table done
# reading (2, 34, '11010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=4.1483 nT --> ddP table done
# reading (2, 34, '11011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.2176 nT --> ddP table done
# reading (2, 34, '11100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.7106 nT --> ddP table done
# reading (2, 34, '11101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.4319 nT --> ddP table done
# reading (2, 34, '11110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.4907 nT --> ddP table done
# reading (2, 34, '11111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.5928 nT --> ddP table done
# reading (3, 34, '00000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.0251 nT --> ddP table done
# reading (3, 34, '00001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9627 nT --> ddP table done
# reading (3, 34, '00010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.3674 nT --> ddP table done
# reading (3, 34, '00011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.1463 nT --> ddP table done
# reading (3, 34, '00100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.8479 nT --> ddP table done
# reading (3, 34, '00101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9655 nT --> ddP table done
# reading (3, 34, '00110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.0301 nT --> ddP table done
# reading (3, 34, '00111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.1797 nT --> ddP table done
# reading (3, 34, '01000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.5926 nT --> ddP table done
# reading (3, 34, '01001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.5609 nT --> ddP table done
# reading (3, 34, '01010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.0317 nT --> ddP table done
# reading (3, 34, '01011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.5684 nT --> ddP table done
# reading (3, 34, '01100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.7827 nT --> ddP table done
# reading (3, 34, '01101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.3003 nT --> ddP table done
# reading (3, 34, '01110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.2175 nT --> ddP table done
# reading (3, 34, '01111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.8647 nT --> ddP table done
# reading (3, 34, '10000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.1355 nT --> ddP table done
# reading (3, 34, '10001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.8613 nT --> ddP table done
# reading (3, 34, '10010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.8878 nT --> ddP table done
# reading (3, 34, '10011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.8603 nT --> ddP table done
# reading (3, 34, '10100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.5242 nT --> ddP table done
# reading (3, 34, '10101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.3248 nT --> ddP table done
# reading (3, 34, '10110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.1252 nT --> ddP table done
# reading (3, 34, '10111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9716 nT --> ddP table done
# reading (3, 34, '11000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.9642 nT --> ddP table done
# reading (3, 34, '11001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.4418 nT --> ddP table done
# reading (3, 34, '11010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.3606 nT --> ddP table done
# reading (3, 34, '11011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.7192 nT --> ddP table done
# reading (3, 34, '11100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.8763 nT --> ddP table done
# reading (3, 34, '11101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=2.8729 nT --> ddP table done
# reading (3, 34, '11110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.8344 nT --> ddP table done
# reading (3, 34, '11111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.2431 nT --> ddP table done
# reading (4, 34, '00000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0581 nT --> ddP table done
# reading (4, 34, '00001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.9844 nT --> ddP table done
# reading (4, 34, '00010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0660 nT --> ddP table done
# reading (4, 34, '00011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2455 nT --> ddP table done
# reading (4, 34, '00100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2413 nT --> ddP table done
# reading (4, 34, '00101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2808 nT --> ddP table done
# reading (4, 34, '00110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.9472 nT --> ddP table done
# reading (4, 34, '00111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1972 nT --> ddP table done
# reading (4, 34, '01000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.4014 nT --> ddP table done
# reading (4, 34, '01001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.3018 nT --> ddP table done
# reading (4, 34, '01010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.9643 nT --> ddP table done
# reading (4, 34, '01011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.5442 nT --> ddP table done
# reading (4, 34, '01100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1294 nT --> ddP table done
# reading (4, 34, '01101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.9858 nT --> ddP table done
# reading (4, 34, '01110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.5940 nT --> ddP table done
# reading (4, 34, '01111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1599 nT --> ddP table done
# reading (4, 34, '10000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0504 nT --> ddP table done
# reading (4, 34, '10001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1571 nT --> ddP table done
# reading (4, 34, '10010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.2283 nT --> ddP table done
# reading (4, 34, '10011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1502 nT --> ddP table done
# reading (4, 34, '10100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0444 nT --> ddP table done
# reading (4, 34, '10101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1766 nT --> ddP table done
# reading (4, 34, '10110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0736 nT --> ddP table done
# reading (4, 34, '10111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.9971 nT --> ddP table done
# reading (4, 34, '11000'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1875 nT --> ddP table done
# reading (4, 34, '11001'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1805 nT --> ddP table done
# reading (4, 34, '11010'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0513 nT --> ddP table done
# reading (4, 34, '11011'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0427 nT --> ddP table done
# reading (4, 34, '11100'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1196 nT --> ddP table done
# reading (4, 34, '11101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.3289 nT --> ddP table done
# reading (4, 34, '11110'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1382 nT --> ddP table done
# reading (4, 34, '11111'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.1658 nT --> ddP table done

# %%
display(LOD_SAddP.T)
display(LOD_SAddP.T.describe())
# Out:
#          0         1       2       3        4
# 0  9.37341   0.17052 2.94184 3.02514 10.05805
# 1  9.37341  35.17073 3.07143 2.96271  9.98440
# 2  9.37341  10.18920 4.04763 3.36740 10.06597
# 3  9.37341   5.81178 2.13161 3.14634 10.24554
# 4  9.37341   2.25806 3.51207 2.84785 10.24132
# 5  9.37341   2.58260 3.19350 2.96552 10.28083
# 6  9.37341 247.81582 5.62161 3.03014  9.94717
# 7  9.37341   9.69270 5.36600 3.17975 10.19725
# 8  9.37341   4.21928 2.80989 3.59257 10.40138
# 9  9.37341  22.67957 2.75293 3.56091 10.30179
# 10 9.37341   1.28978 3.07622 3.03171  9.96434
# 11 9.37341   9.52001 3.23404 3.56841 10.54419
# 12 9.37341  11.64490 5.40671 2.78269 10.12938
# 13 9.37341  14.43049 3.85384 3.30029  9.98579
# 14 9.37341   9.69001 2.58157 3.21755 10.59398
# 15 9.37341   7.13918 3.67622 2.86472 10.15989
# 16 9.37341  68.24114 4.57389 3.13554 10.05043
# 17 9.37341   9.69270 4.79472 2.86134 10.15708
# 18 9.37341  17.45915 4.34966 3.88781 10.22831
# 19 9.37341  16.00294 3.86405 2.86029 10.15017
# 20 9.37341  11.03012 1.99583 2.52416 10.04440
# 21 9.37341  59.04451 2.28682 3.32484 10.17658
# 22 9.37341   1.92535 2.37851 3.12521 10.07360
# 23 9.37341   2.88041 3.66501 2.97162  9.99714
# 24 9.37341   9.69001 2.57115 2.96424 10.18755
# 25 9.37341   7.15251 4.79900 3.44182 10.18052
# 26 9.37341  83.18410 4.14833 3.36061 10.05131
# 27 9.37341   9.49942 3.21763 2.71920 10.04272
# 28 9.37341  26.57067 2.71064 3.87627 10.11963
# 29 9.37341   9.52001 2.43189 2.87288 10.32892
# 30 9.37341   4.40170 3.49070 3.83436 10.13819
# 31 9.37341   6.23680 3.59279 3.24311 10.16575
#              0         1        2        3        4
# count 32.00000  32.00000 32.00000 32.00000 32.00000
# mean   9.37341  23.02613  3.50462  3.17022 10.16230
# std    0.00000  45.43024  0.98685  0.34173  0.15354
# min    9.37341   0.17052  1.99583  2.52416  9.94717
# 25%    9.37341   5.45926  2.74236  2.94025 10.05109
# 50%    9.37341   9.69001  3.36237  3.13037 10.15363
# 75%    9.37341  16.36699  4.07281  3.36231 10.23156
# max    9.37341 247.81582  5.62161  3.88781 10.59398

# %%
# plot SA Energy series for s=29
plot_table = LOD_SAddP

for diff in [0, 1, 2]:

    fig, ax = plt.subplots(1, 1, figsize=(12, 9))

    cmap = mpl.colormaps['cool']
    norm = BoundaryNorm(plot_table.columns, cmap.N)
    seed_l = plot_table.columns[0:31:2]

    for s in [29]:
        b_seed = format(s, '05b')
        hindcast = np.load(f"{save_dir}/d{diff}g_{Drec}_{b_seed}_geomag_memos.npz", allow_pickle=True)

        SA_time = hindcast['time_memo'] - 0.2502  # adjust time for SA leapfrog
        SA_memo = hindcast['d2g_memo'] # RNN prediction of SA

        SA_memo = if_nan_SAgenerate(SA_memo, hindcast, diff=diff)

        SA_Energy_col = get_energy(SA_memo[:J, :], SA_time, hindcast['columns'][:J])
        SA_Energy_tot = SA_Energy_col[1:, :].sum(axis=0)

        # print(SA_Energy_col[0, :], SA_Energy_tot)

        ax.plot(SA_Energy_col[0, :], SA_Energy_tot, 
                c=cmap(norm(s)), alpha=0.7)


    SA_ref = coef_raw[2].loc[hindcast['time_memo'], :].values.T # Reference SA time series
    SA_Energy_ref_col = get_energy(SA_ref, hindcast['time_memo'] - 0.2502, hindcast['columns'][:J])
    SA_Energy_ref_tot = SA_Energy_ref_col[1:, :].sum(axis=0)
    ax.plot(SA_Energy_ref_col[0, :], SA_Energy_ref_tot, c='black', label='MCM-2024')


    p = ax.scatter([np.nan]*32, [np.nan]*32, cmap=cmap, norm=norm, c=range(32), alpha=1.0, marker='none')
    ax.colorbar = plt.colorbar(p, ax=ax)
    ax.colorbar.set_label(r"Random Seed  $s$", fontsize=f_large)
    # print([f"{seed} ({format(seed, '05b')})" for seed in seed_l])
    ax.colorbar.set_ticks                                                    (seed_l)
    ax.colorbar.set_ticklabels([f"{seed} ({format(seed, '05b')})" for seed in seed_l])


    ymin, ymax = 0, 200
    ax.set_ylim(ymin, ymax)

    ax.fill_between(hindcast['time_memo'], ymin, ymax, 
                    where=(hindcast['time_memo']>=fS) & (hindcast['time_memo']<=fE), 
                    color='yellow', alpha=0.5, label=f'Hindcast period ({fS:.2f} - {fE:.2f})')
    ax.fill_between(hindcast['time_memo'], ymin, ymax, 
                    where=(hindcast['time_memo']>=TS-0.2502) & (hindcast['time_memo']<=TE-0.2502), 
                    color='orange', alpha=0.5, label=f'2015 Pulse ({TS-0.25:.2f} - {TE-0.25:.2f})')

    ax.set_xlabel('Date (year)', fontsize=f_large)
    ax.set_ylabel(r"SA Energy  (nT/yr$^2$)$^2$", fontsize=f_large)
    ax.set_title(r"SA Energy  (nT/yr$^2$)$^2$   (Trained with Gauss coefs. + LOD)" + 
                f"\n Derivative d={diff} | Seed s=11101 | Drec=34" + 
                f"\n Error/Misfit time: {TS-0.2502:.4f} ≦ t ≦ {TE-0.2502:.4f} \n", 
                fontsize=f_large)
    ax.legend(fontsize=f_large)
    plt.tight_layout()
    plt.show()
# Out:
#   --> NaN found in SA_memo, generating SA from CF series...
#   --> NaN found in SA_memo, generating SA from SV series...

# %% [markdown]
# ### d(LOD)/dt data (LDT-RNN)

# %%
### Compute ddP table
LDT_SAddP = pd.DataFrame(index=np.arange(0, 5), columns=np.arange(0, 32), dtype=float)

save_dir = "../output/2025_1205_yBnLODyLDT_h34_s0-32"

for d_max in range(5):
    for seed in range(0, 32):
        b_seed = format(seed, '05b') # seed No. as 5-bit binary

        filename = f"d{d_max}g_{Drec}_{b_seed}_geomag_memos.npz"

        read_file = f"{save_dir}/{filename}"

        print(f"reading {(d_max, Drec, b_seed)}: ", end="")

        try:
            pred_memos = np.load(read_file, allow_pickle=True)
        except Exception as e:
            print(f"Error loading {read_file}: {e}")
            continue
        
        print(f"loaded --> ", end="\n")
        
        CF_time = pred_memos['time_memo']       # time - leap frog
        CF_cols = pred_memos['columns'][:J]   # target field columns, exclude LOD at the end
        SA_memo = pred_memos['d2g_memo']        # RNN prediction of SA

        SA_memo = if_nan_SAgenerate(SA_memo, pred_memos, diff=d_max)

        TG_memo = SA_memo[:J, :] # target field (exclude LOD at the end)

        print(f"time={CF_time.shape}, shape={TG_memo.shape} --> ", end="")

        # t_idx = np.where(CF_time == target_epoch)[0][0]
        # print(f"t_idx={fE_idx} --> ", end="")

        # 範囲インデックス配列の作成
        # tS_idx = np.abs(CF_time - TS).argmin()
        # tE_idx = np.abs(CF_time - TE).argmin()
        # t_indices = np.arange(tS_idx, tE_idx + 1)

        t_idx = np.abs(CF_time - TT).argmin()
        t_indices = [t_idx]
        print(f"t_indices from {t_indices[0]} to {t_indices[-1]} ({len(t_indices)} points) --> ", end="")

        TG_rnn = TG_memo[:, t_indices] # multiple time steps
        error  = TG_rnn - TG_ref
        print("error.shape: ", error.shape, len(CF_cols), "--> ", end="")
        
        ddP2 = get_energy(error, CF_time[t_indices], CF_cols)
        # print("ddP2:", ddP2)
        print("ddP2.shape", ddP2.shape, len(CF_cols), "--> ", end="")
        # sqrtddP = np.sqrt(np.trapz(ddP2[1:, :].sum(axis=0), CF_time[t_indices])) # integrate over time
        sqrtddP = np.sqrt(ddP2[1:, :].sum()) # integrate over time

        print(f"sqrt(ddP)={sqrtddP:.4f} nT --> ", end="")
        LDT_SAddP.loc[d_max, seed] = sqrtddP

        print("ddP table done", end="\n")
# Out:
# reading (0, 34, '00000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00000_geomag_memos.npz'
# reading (0, 34, '00001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00001_geomag_memos.npz'
# reading (0, 34, '00010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00010_geomag_memos.npz'
# reading (0, 34, '00011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00011_geomag_memos.npz'
# reading (0, 34, '00100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00100_geomag_memos.npz'
# reading (0, 34, '00101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00101_geomag_memos.npz'
# reading (0, 34, '00110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00110_geomag_memos.npz'
# reading (0, 34, '00111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_00111_geomag_memos.npz'
# reading (0, 34, '01000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01000_geomag_memos.npz'
# reading (0, 34, '01001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01001_geomag_memos.npz'
# reading (0, 34, '01010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01010_geomag_memos.npz'
# reading (0, 34, '01011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01011_geomag_memos.npz'
# reading (0, 34, '01100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01100_geomag_memos.npz'
# reading (0, 34, '01101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01101_geomag_memos.npz'
# reading (0, 34, '01110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01110_geomag_memos.npz'
# reading (0, 34, '01111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_01111_geomag_memos.npz'
# reading (0, 34, '10000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10000_geomag_memos.npz'
# reading (0, 34, '10001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10001_geomag_memos.npz'
# reading (0, 34, '10010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10010_geomag_memos.npz'
# reading (0, 34, '10011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10011_geomag_memos.npz'
# reading (0, 34, '10100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10100_geomag_memos.npz'
# reading (0, 34, '10101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10101_geomag_memos.npz'
# reading (0, 34, '10110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10110_geomag_memos.npz'
# reading (0, 34, '10111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_10111_geomag_memos.npz'
# reading (0, 34, '11000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11000_geomag_memos.npz'
# reading (0, 34, '11001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11001_geomag_memos.npz'
# reading (0, 34, '11010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11010_geomag_memos.npz'
# reading (0, 34, '11011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11011_geomag_memos.npz'
# reading (0, 34, '11100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11100_geomag_memos.npz'
# reading (0, 34, '11101'): loaded -->
#   --> NaN found in SA_memo, generating SA from CF series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.3734 nT --> ddP table done
# reading (0, 34, '11110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11110_geomag_memos.npz'
# reading (0, 34, '11111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d0g_34_11111_geomag_memos.npz'
# reading (1, 34, '00000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00000_geomag_memos.npz'
# reading (1, 34, '00001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00001_geomag_memos.npz'
# reading (1, 34, '00010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00010_geomag_memos.npz'
# reading (1, 34, '00011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00011_geomag_memos.npz'
# reading (1, 34, '00100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00100_geomag_memos.npz'
# reading (1, 34, '00101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00101_geomag_memos.npz'
# reading (1, 34, '00110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00110_geomag_memos.npz'
# reading (1, 34, '00111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_00111_geomag_memos.npz'
# reading (1, 34, '01000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01000_geomag_memos.npz'
# reading (1, 34, '01001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01001_geomag_memos.npz'
# reading (1, 34, '01010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01010_geomag_memos.npz'
# reading (1, 34, '01011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01011_geomag_memos.npz'
# reading (1, 34, '01100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01100_geomag_memos.npz'
# reading (1, 34, '01101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01101_geomag_memos.npz'
# reading (1, 34, '01110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01110_geomag_memos.npz'
# reading (1, 34, '01111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_01111_geomag_memos.npz'
# reading (1, 34, '10000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10000_geomag_memos.npz'
# reading (1, 34, '10001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10001_geomag_memos.npz'
# reading (1, 34, '10010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10010_geomag_memos.npz'
# reading (1, 34, '10011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10011_geomag_memos.npz'
# reading (1, 34, '10100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10100_geomag_memos.npz'
# reading (1, 34, '10101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10101_geomag_memos.npz'
# reading (1, 34, '10110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10110_geomag_memos.npz'
# reading (1, 34, '10111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_10111_geomag_memos.npz'
# reading (1, 34, '11000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11000_geomag_memos.npz'
# reading (1, 34, '11001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11001_geomag_memos.npz'
# reading (1, 34, '11010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11010_geomag_memos.npz'
# reading (1, 34, '11011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11011_geomag_memos.npz'
# reading (1, 34, '11100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11100_geomag_memos.npz'
# reading (1, 34, '11101'): loaded -->
#   --> NaN found in SA_memo, generating SA from SV series...
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=9.5270 nT --> ddP table done
# reading (1, 34, '11110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11110_geomag_memos.npz'
# reading (1, 34, '11111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d1g_34_11111_geomag_memos.npz'
# reading (2, 34, '00000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00000_geomag_memos.npz'
# reading (2, 34, '00001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00001_geomag_memos.npz'
# reading (2, 34, '00010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00010_geomag_memos.npz'
# reading (2, 34, '00011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00011_geomag_memos.npz'
# reading (2, 34, '00100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00100_geomag_memos.npz'
# reading (2, 34, '00101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00101_geomag_memos.npz'
# reading (2, 34, '00110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00110_geomag_memos.npz'
# reading (2, 34, '00111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_00111_geomag_memos.npz'
# reading (2, 34, '01000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01000_geomag_memos.npz'
# reading (2, 34, '01001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01001_geomag_memos.npz'
# reading (2, 34, '01010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01010_geomag_memos.npz'
# reading (2, 34, '01011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01011_geomag_memos.npz'
# reading (2, 34, '01100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01100_geomag_memos.npz'
# reading (2, 34, '01101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01101_geomag_memos.npz'
# reading (2, 34, '01110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01110_geomag_memos.npz'
# reading (2, 34, '01111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_01111_geomag_memos.npz'
# reading (2, 34, '10000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10000_geomag_memos.npz'
# reading (2, 34, '10001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10001_geomag_memos.npz'
# reading (2, 34, '10010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10010_geomag_memos.npz'
# reading (2, 34, '10011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10011_geomag_memos.npz'
# reading (2, 34, '10100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10100_geomag_memos.npz'
# reading (2, 34, '10101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10101_geomag_memos.npz'
# reading (2, 34, '10110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10110_geomag_memos.npz'
# reading (2, 34, '10111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_10111_geomag_memos.npz'
# reading (2, 34, '11000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11000_geomag_memos.npz'
# reading (2, 34, '11001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11001_geomag_memos.npz'
# reading (2, 34, '11010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11010_geomag_memos.npz'
# reading (2, 34, '11011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11011_geomag_memos.npz'
# reading (2, 34, '11100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11100_geomag_memos.npz'
# reading (2, 34, '11101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.0831 nT --> ddP table done
# reading (2, 34, '11110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11110_geomag_memos.npz'
# reading (2, 34, '11111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d2g_34_11111_geomag_memos.npz'
# reading (3, 34, '00000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00000_geomag_memos.npz'
# reading (3, 34, '00001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00001_geomag_memos.npz'
# reading (3, 34, '00010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00010_geomag_memos.npz'
# reading (3, 34, '00011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00011_geomag_memos.npz'
# reading (3, 34, '00100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00100_geomag_memos.npz'
# reading (3, 34, '00101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00101_geomag_memos.npz'
# reading (3, 34, '00110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00110_geomag_memos.npz'
# reading (3, 34, '00111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_00111_geomag_memos.npz'
# reading (3, 34, '01000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01000_geomag_memos.npz'
# reading (3, 34, '01001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01001_geomag_memos.npz'
# reading (3, 34, '01010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01010_geomag_memos.npz'
# reading (3, 34, '01011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01011_geomag_memos.npz'
# reading (3, 34, '01100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01100_geomag_memos.npz'
# reading (3, 34, '01101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01101_geomag_memos.npz'
# reading (3, 34, '01110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01110_geomag_memos.npz'
# reading (3, 34, '01111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_01111_geomag_memos.npz'
# reading (3, 34, '10000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10000_geomag_memos.npz'
# reading (3, 34, '10001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10001_geomag_memos.npz'
# reading (3, 34, '10010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10010_geomag_memos.npz'
# reading (3, 34, '10011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10011_geomag_memos.npz'
# reading (3, 34, '10100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10100_geomag_memos.npz'
# reading (3, 34, '10101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10101_geomag_memos.npz'
# reading (3, 34, '10110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10110_geomag_memos.npz'
# reading (3, 34, '10111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_10111_geomag_memos.npz'
# reading (3, 34, '11000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11000_geomag_memos.npz'
# reading (3, 34, '11001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11001_geomag_memos.npz'
# reading (3, 34, '11010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11010_geomag_memos.npz'
# reading (3, 34, '11011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11011_geomag_memos.npz'
# reading (3, 34, '11100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11100_geomag_memos.npz'
# reading (3, 34, '11101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=3.2764 nT --> ddP table done
# reading (3, 34, '11110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11110_geomag_memos.npz'
# reading (3, 34, '11111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d3g_34_11111_geomag_memos.npz'
# reading (4, 34, '00000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00000_geomag_memos.npz'
# reading (4, 34, '00001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00001_geomag_memos.npz'
# reading (4, 34, '00010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00010_geomag_memos.npz'
# reading (4, 34, '00011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00011_geomag_memos.npz'
# reading (4, 34, '00100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00100_geomag_memos.npz'
# reading (4, 34, '00101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00101_geomag_memos.npz'
# reading (4, 34, '00110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00110_geomag_memos.npz'
# reading (4, 34, '00111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_00111_geomag_memos.npz'
# reading (4, 34, '01000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01000_geomag_memos.npz'
# reading (4, 34, '01001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01001_geomag_memos.npz'
# reading (4, 34, '01010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01010_geomag_memos.npz'
# reading (4, 34, '01011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01011_geomag_memos.npz'
# reading (4, 34, '01100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01100_geomag_memos.npz'
# reading (4, 34, '01101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01101_geomag_memos.npz'
# reading (4, 34, '01110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01110_geomag_memos.npz'
# reading (4, 34, '01111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_01111_geomag_memos.npz'
# reading (4, 34, '10000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10000_geomag_memos.npz'
# reading (4, 34, '10001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10001_geomag_memos.npz'
# reading (4, 34, '10010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10010_geomag_memos.npz'
# reading (4, 34, '10011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10011_geomag_memos.npz'
# reading (4, 34, '10100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10100_geomag_memos.npz'
# reading (4, 34, '10101'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10101_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10101_geomag_memos.npz'
# reading (4, 34, '10110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10110_geomag_memos.npz'
# reading (4, 34, '10111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_10111_geomag_memos.npz'
# reading (4, 34, '11000'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11000_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11000_geomag_memos.npz'
# reading (4, 34, '11001'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11001_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11001_geomag_memos.npz'
# reading (4, 34, '11010'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11010_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11010_geomag_memos.npz'
# reading (4, 34, '11011'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11011_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11011_geomag_memos.npz'
# reading (4, 34, '11100'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11100_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11100_geomag_memos.npz'
# reading (4, 34, '11101'): loaded -->
# time=(76,), shape=(195, 76) --> t_indices from 44 to 44 (1 points) --> error.shape:  (195, 1) 195 --> ddP2.shape (14, 1) 195 --> sqrt(ddP)=10.0787 nT --> ddP table done
# reading (4, 34, '11110'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11110_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11110_geomag_memos.npz'
# reading (4, 34, '11111'): Error loading ../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11111_geomag_memos.npz: [Errno 2] No such file or directory: '../output/2025_1205_yBnLODyLDT_h34_s0-32/d4g_34_11111_geomag_memos.npz'

# %%
display(LDT_SAddP.T)
display(LDT_SAddP.T.describe())
# Out:
#          0       1       2       3        4
# 0      NaN     NaN     NaN     NaN      NaN
# 1      NaN     NaN     NaN     NaN      NaN
# 2      NaN     NaN     NaN     NaN      NaN
# 3      NaN     NaN     NaN     NaN      NaN
# 4      NaN     NaN     NaN     NaN      NaN
# 5      NaN     NaN     NaN     NaN      NaN
# 6      NaN     NaN     NaN     NaN      NaN
# 7      NaN     NaN     NaN     NaN      NaN
# 8      NaN     NaN     NaN     NaN      NaN
# 9      NaN     NaN     NaN     NaN      NaN
# 10     NaN     NaN     NaN     NaN      NaN
# 11     NaN     NaN     NaN     NaN      NaN
# 12     NaN     NaN     NaN     NaN      NaN
# 13     NaN     NaN     NaN     NaN      NaN
# 14     NaN     NaN     NaN     NaN      NaN
# 15     NaN     NaN     NaN     NaN      NaN
# 16     NaN     NaN     NaN     NaN      NaN
# 17     NaN     NaN     NaN     NaN      NaN
# 18     NaN     NaN     NaN     NaN      NaN
# 19     NaN     NaN     NaN     NaN      NaN
# 20     NaN     NaN     NaN     NaN      NaN
# 21     NaN     NaN     NaN     NaN      NaN
# 22     NaN     NaN     NaN     NaN      NaN
# 23     NaN     NaN     NaN     NaN      NaN
# 24     NaN     NaN     NaN     NaN      NaN
# 25     NaN     NaN     NaN     NaN      NaN
# 26     NaN     NaN     NaN     NaN      NaN
# 27     NaN     NaN     NaN     NaN      NaN
# 28     NaN     NaN     NaN     NaN      NaN
# 29 9.37341 9.52704 3.08306 3.27638 10.07869
# 30     NaN     NaN     NaN     NaN      NaN
# 31     NaN     NaN     NaN     NaN      NaN
#             0       1       2       3        4
# count 1.00000 1.00000 1.00000 1.00000  1.00000
# mean  9.37341 9.52704 3.08306 3.27638 10.07869
# std       NaN     NaN     NaN     NaN      NaN
# min   9.37341 9.52704 3.08306 3.27638 10.07869
# 25%   9.37341 9.52704 3.08306 3.27638 10.07869
# 50%   9.37341 9.52704 3.08306 3.27638 10.07869
# 75%   9.37341 9.52704 3.08306 3.27638 10.07869
# max   9.37341 9.52704 3.08306 3.27638 10.07869

# %% [markdown]
# ## SA time series plot
#
# ### MCM-RNN vs LOD-RNN

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 12))

ax.plot(MCM_SAddP.index, MCM_SAddP.loc[:, IGRF_s].values, 
        marker="o", markersize=20, markeredgewidth=2, linestyle="-", linewidth=2.0, color="blue", 
        markerfacecolor='blue', markeredgecolor='blue', 
        label="Trained with Gauss coefs.")

ax.plot(LOD_SAddP.index, LOD_SAddP.loc[:, IGRF_s].values, 
        marker="o", markersize=20, markeredgewidth=2, linestyle="-", linewidth=2.0, color="red", 
        markerfacecolor='red', markeredgecolor='red', 
        label="Trained with Gauss coefs. + LOD data")

ax.set_xticks(range(5))
ax.tick_params(axis='x', labelsize=f_large)
ax.set_yticks(range(15))
ax.set_ylim(0, 14)
ax.tick_params(axis='y', labelsize=f_medium)
# ax.set_yscale('log')
ax.set_xlabel(r"Order of derivatives  $d$", fontsize=f_large)
ax.set_ylabel(r"Training Misfit in $\sqrt{\mathrm{SA \ Energy}}$    $\left[ \ \sqrt{nT^2/yr} \ \right]$", fontsize=f_medium)

ax.set_title(f"IGRF submitted parameters result" + 
             "\n Seed s=11101 | Drec=34" + 
             f"\n Error/Misfit time: t = {TT-0.2502:.4f} \n", 
             fontsize=f_medium)
plt.legend(fontsize=f_medium, loc='upper left')
plt.tight_layout()
plt.show()

# %%
# plot SA Energy series for s=29
diff = 2
s = 29
b_seed = format(s, '05b')
print(f"Plotting for d={diff}, s={s} ({b_seed})")

fig, ax = plt.subplots(1, 1, figsize=(16, 12))

## Trained without LOD ----------------------------------
MCM = np.load(f"../output/2025_1017_yBnLODnLDT_h34_s0-32/d{diff}g_{Drec}_{b_seed}_geomag_memos.npz", allow_pickle=True)

MCM_SA_time = MCM['time_memo'] - 0.2502  # adjust time for SA leapfrog
MCM_SA_memo = MCM['d2g_memo'] # RNN prediction of SA

MCM_SA_Energy_col = get_energy(MCM_SA_memo[:J, :], MCM_SA_time, MCM['columns'][:J])
MCM_SA_Energy_tot = MCM_SA_Energy_col[1:, :].sum(axis=0)

# print(SA_Energy_col[0, :], SA_Energy_tot)

ax.plot(MCM_SA_Energy_col[0, :], MCM_SA_Energy_tot, 
        color="blue", linewidth=4.0,
        label="Trained with Gauss coefs.")

## Trained with LOD ----------------------------------
LOD = np.load(f"../output/2025_1108_yByLODnLDT_h34_s0-32/d{diff}g_{Drec}_{b_seed}_geomag_memos.npz", allow_pickle=True)

LOD_SA_time = LOD['time_memo'] - 0.2502  # adjust time for SA leapfrog
LOD_SA_memo = LOD['d2g_memo'] # RNN prediction of SA

LOD_SA_Energy_col = get_energy(LOD_SA_memo[:J, :], LOD_SA_time, LOD['columns'][:J])
LOD_SA_Energy_tot = LOD_SA_Energy_col[1:, :].sum(axis=0)

# print(SA_Energy_col[0, :], SA_Energy_tot)

ax.plot(LOD_SA_Energy_col[0, :], LOD_SA_Energy_tot, 
        color="red", linewidth=4.0,
        label="Trained with Gauss coefs. + LOD data")

# print(SA_Energy_col[0, :], SA_Energy_tot)

## Reference ----------------------------------

SA_ref = coef_raw[2].loc[MCM['time_memo'], :].values.T # Reference SA time series
SA_Energy_ref_col = get_energy(SA_ref, MCM['time_memo'] - 0.2502, MCM['columns'][:J])
SA_Energy_ref_tot = SA_Energy_ref_col[1:, :].sum(axis=0)
ax.plot(SA_Energy_ref_col[0, :], SA_Energy_ref_tot, 
        c='black', linewidth=6.0,
        label='MCM-2024')

ymin, ymax = 0, 200
ax.set_ylim(ymin, ymax)

ax.fill_between(MCM['time_memo'], ymin, ymax, 
            where=(MCM['time_memo']>=fS) & (MCM['time_memo']<=fE), 
            color='yellow', alpha=0.5, label=f'Hindcast period ({fS:.2f} - {fE:.2f})')
ax.fill_between(MCM['time_memo'], ymin, ymax, 
            where=(MCM['time_memo']>=TS-0.2502) & (MCM['time_memo']<=TE-0.2502), 
            color='orange', alpha=0.5, label=f'2015 Pulse ({TS-0.25:.2f} - {TE-0.25:.2f})')

ax.set_xlabel('Date (year)', fontsize=f_large)
ax.set_ylabel(r"Secular Acceleration Energy  (nT/yr$^2$)$^2$", fontsize=f_large)
ax.set_title(r"SA Energy  (nT/yr$^2$)$^2$   (Trained with Gauss coefs. + LOD)" + 
        f"\n Derivative d={diff} | Seed s=11101 | Drec=34" + 
        f"\n Error/Misfit time: {TS-0.2502:.4f} ≦ t ≦ {TE-0.2502:.4f} \n", 
        fontsize=f_large)
ax.legend(fontsize=f_medium, loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Plotting for d=2, s=29 (11101)

# %% [markdown]
# ### MCM- vs LOD- vs LDT-RNN

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 12))

ax.plot(MCM_SAddP.index, MCM_SAddP.loc[:, IGRF_s].values, 
        marker="o", markersize=20, markeredgewidth=2, linestyle="-", linewidth=2.0, color="blue", 
        markerfacecolor='blue', markeredgecolor='blue', 
        label="Trained with Gauss coefs.")

ax.plot(LOD_SAddP.index, LOD_SAddP.loc[:, IGRF_s].values, 
        marker="o", markersize=20, markeredgewidth=2, linestyle="-", linewidth=2.0, color="red", 
        markerfacecolor='red', markeredgecolor='red', 
        label="Trained with Gauss coefs. + LOD data")

ax.plot(LDT_SAddP.index, LDT_SAddP.loc[:, IGRF_s].values, 
        marker="o", markersize=20, markeredgewidth=2, linestyle="-", linewidth=2.0, color="red", 
        markerfacecolor='white', markeredgecolor='red', 
        label="Trained with Gauss coefs. + d(LOD)/dt data")

ax.set_xticks(range(5))
ax.tick_params(axis='x', labelsize=f_large)
ax.set_yticks(range(15))
ax.set_ylim(0, 14)
ax.tick_params(axis='y', labelsize=f_medium)
# ax.set_yscale('log')
ax.set_xlabel(r"Order of derivatives  $d$", fontsize=f_large)
ax.set_ylabel(r"Training Misfit in $\sqrt{\mathrm{SA \ Energy}}$    $\left[ \ \sqrt{nT^2/yr} \ \right]$", fontsize=f_medium)

ax.set_title(f"IGRF submitted parameters result" + 
             "\n Seed s=11101 | Drec=34" + 
             f"\n Error/Misfit time: t = {TT-0.2502:.4f} \n", 
             fontsize=f_medium)
plt.legend(fontsize=f_medium, loc='upper left')
plt.tight_layout()
plt.show()

# %%
# plot SA Energy series for s=29
diff = 2
s = 29
b_seed = format(s, '05b')
print(f"Plotting for d={diff}, s={s} ({b_seed})")

fig, ax = plt.subplots(1, 1, figsize=(16, 12))

## Trained without LOD ----------------------------------
MCM = np.load(f"../output/2025_1017_yBnLODnLDT_h34_s0-32/d{diff}g_{Drec}_{b_seed}_geomag_memos.npz", allow_pickle=True)

MCM_SA_time = MCM['time_memo'] - 0.2502  # adjust time for SA leapfrog
MCM_SA_memo = MCM['d2g_memo'] # RNN prediction of SA

MCM_SA_Energy_col = get_energy(MCM_SA_memo[:J, :], MCM_SA_time, MCM['columns'][:J])
MCM_SA_Energy_tot = MCM_SA_Energy_col[1:, :].sum(axis=0)

# print(SA_Energy_col[0, :], SA_Energy_tot)

ax.plot(MCM_SA_Energy_col[0, :], MCM_SA_Energy_tot, 
        color="blue", linewidth=4.0,
        label="Trained with Gauss coefs.")

## Trained with LOD ----------------------------------
LOD = np.load(f"../output/2025_1108_yByLODnLDT_h34_s0-32/d{diff}g_{Drec}_{b_seed}_geomag_memos.npz", allow_pickle=True)

LOD_SA_time = LOD['time_memo'] - 0.2502  # adjust time for SA leapfrog
LOD_SA_memo = LOD['d2g_memo'] # RNN prediction of SA

LOD_SA_Energy_col = get_energy(LOD_SA_memo[:J, :], LOD_SA_time, LOD['columns'][:J])
LOD_SA_Energy_tot = LOD_SA_Energy_col[1:, :].sum(axis=0)

# print(SA_Energy_col[0, :], SA_Energy_tot)

ax.plot(LOD_SA_Energy_col[0, :], LOD_SA_Energy_tot, 
        color="red", linewidth=4.0,
        label="Trained with Gauss coefs. + LOD data")

## Trained with LDT ----------------------------------
LDT = np.load(f"../output/2025_1205_yBnLODyLDT_h34_s0-32/d{diff}g_{Drec}_{b_seed}_geomag_memos.npz", allow_pickle=True)

LDT_SA_time = LDT['time_memo'] - 0.2502  # adjust time for SA leapfrog
LDT_SA_memo = LDT['d2g_memo'] # RNN prediction of SA

LDT_SA_Energy_col = get_energy(LDT_SA_memo[:J, :], LDT_SA_time, LDT['columns'][:J])
LDT_SA_Energy_tot = LDT_SA_Energy_col[1:, :].sum(axis=0)

# print(SA_Energy_col[0, :], SA_Energy_tot)

ax.plot(LDT_SA_Energy_col[0, :], LDT_SA_Energy_tot, 
        color="purple", linewidth=4.0,
        label="Trained with Gauss coefs. + d(LOD)/dt")

## Reference ----------------------------------

SA_ref = coef_raw[2].loc[MCM['time_memo'], :].values.T # Reference SA time series
SA_Energy_ref_col = get_energy(SA_ref, MCM['time_memo'] - 0.2502, MCM['columns'][:J])
SA_Energy_ref_tot = SA_Energy_ref_col[1:, :].sum(axis=0)
ax.plot(SA_Energy_ref_col[0, :], SA_Energy_ref_tot, 
        c='black', linewidth=6.0,
        label='MCM-2024')

ymin, ymax = 0, 200
ax.set_ylim(ymin, ymax)

ax.fill_between(MCM['time_memo'], ymin, ymax, 
            where=(MCM['time_memo']>=fS) & (MCM['time_memo']<=fE), 
            color='yellow', alpha=0.5, label=f'Hindcast period ({fS:.2f} - {fE:.2f})')
ax.fill_between(MCM['time_memo'], ymin, ymax, 
            where=(MCM['time_memo']>=TS-0.2502) & (MCM['time_memo']<=TE-0.2502), 
            color='orange', alpha=0.5, label=f'2015 Pulse ({TS-0.25:.2f} - {TE-0.25:.2f})')

ax.set_xlabel('Date (year)', fontsize=f_large)
ax.set_ylabel(r"Secular Acceleration Energy  (nT/yr$^2$)$^2$", fontsize=f_large)
ax.set_title(r"SA Energy  (nT/yr$^2$)$^2$   (Trained with Gauss coefs. + LOD)" + 
        f"\n Derivative d={diff} | Seed s=11101 | Drec=34" + 
        f"\n Error/Misfit time: {TS-0.2502:.4f} ≦ t ≦ {TE-0.2502:.4f} \n", 
        fontsize=f_large)
ax.legend(fontsize=f_medium, loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Plotting for d=2, s=29 (11101)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 12))

LOD_raw = pd.read_csv(f"{mcm_load}/lod.csv")
print(LOD_raw.head())
LOD_raw.set_index('YEAR', inplace=True)

LDT_raw = pd.read_csv(f"{mcm_load}/DlodDT.csv")
print(LDT_raw.head())
LDT_raw.set_index('YEAR', inplace=True)


ax.plot(LOD['time_memo'], LOD['d2g_memo'][-1, :], 
        color="red", linewidth=4.0,
        label="EKF-RNN prediction (LOD)") # RNN prediction of LOD)

ti0 = 0
tiE = 57
ax.plot(LDT['time_memo'][ti0:tiE], LDT['d2g_memo'][-1, ti0:tiE] * 0.25 + LOD_raw['avg_lod'].values[ti0:tiE],
        color="purple", linewidth=4.0,
        label="EKF-RNN prediction d(LOD)/dt") # RNN prediction of LOD)

ax.plot(LDT['time_memo'][tiE:], LDT['d2g_memo'][-1, tiE:].cumsum() * 0.25 + LOD_raw['avg_lod'].values[tiE],
        color="purple", linewidth=4.0) # RNN prediction of LOD)


ax.plot(LOD_raw.index.values, LOD_raw['avg_lod'].values,
        color="green", linewidth=6.0,
        label="Original LOD data with $\pm 2σ$ uncertainty (IERS)") # RNN prediction of LOD)

ax.fill_between(LOD_raw.index.values, 
                LOD_raw['avg_lod'].values - sig * LOD_raw['std_lod'].values,
                LOD_raw['avg_lod'].values + sig * LOD_raw['std_lod'].values,
                color='gray', alpha=0.5)

ymin, ymax = -1.5, 2.0
ax.set_ylim(ymin, ymax)

ax.fill_between(MCM['time_memo'], ymin, ymax, 
            where=(MCM['time_memo']>=fS) & (MCM['time_memo']<=fE), 
            color='yellow', alpha=0.5, label=f'Hindcast period ({fS:.2f} - {fE:.2f})')
ax.fill_between(MCM['time_memo'], ymin, ymax, 
            where=(MCM['time_memo']>=TS-0.2502) & (MCM['time_memo']<=TE-0.2502), 
            color='orange', alpha=0.5, label=f'2015 Pulse ({TS-0.25:.2f} - {TE-0.25:.2f})')

ax.plot([2000, 2030], [0, 0], 'k--', linewidth=2.0)
ax.set_xlim(2004, 2027)

ax.set_xlabel('Date (year)', fontsize=f_large)
ax.set_ylabel("ΔLOD (Excess 86400 sec.)   [ms]", fontsize=f_large)
ax.set_title(r"LOD output [ms] (Trained with Gauss coefs. + LOD)" + 
        f"\n Derivative d={diff} | Seed s=11101 | Drec=34" + 
        f"\n Error/Misfit time: {TS-0.2502:.4f} ≦ t ≦ {TE-0.2502:.4f} \n", 
        fontsize=f_large)
ax.legend(fontsize=f_large, loc='lower left')
plt.tight_layout()
plt.show()
# Out:
#         YEAR  avg_lod  std_lod
# 0 2004.87390  0.52743  0.41846
# 1 2005.12370  0.54405  0.39114
# 2 2005.37390  0.56549  0.38475
# 3 2005.62410  0.57278  0.39421
# 4 2005.87420  0.61620  0.43387
#         YEAR  avg_lod  std_lod
# 0 2005.12390  0.29403  2.21533
# 1 2005.37370  0.06493  2.29257
# 2 2005.62390  0.09109  2.19548
# 3 2005.87410  0.02917  2.20340
# 4 2006.12420  0.17366  2.34486

# %%
#d(lod)/dt

fig, ax = plt.subplots(1, 1, figsize=(16, 12))

ax.plot(LOD['time_memo'][:-1], np.diff(LOD['d2g_memo'][-1, :]) / dt, 
        color="red", linewidth=4.0,
        label="EKF-RNN prediction (LOD)") # RNN prediction of LOD)
ax.plot(LDT['time_memo'][:], LDT['d1g_memo'][-1, :], 
        color="purple", linewidth=4.0,
        label="EKF-RNN prediction (d(LOD)/dt)") # RNN prediction of LOD)


LDT_raw = pd.read_csv(f"{mcm_load}/DlodDT.csv")
print(LDT_raw.head())

LDT_raw.set_index('YEAR', inplace=True)

ax.plot(LDT_raw.index.values, LDT_raw['avg_lod'],
        color="green", linewidth=6.0,
        label="Original d(LOD)/dt data (IERS)")#  with $\pm 2σ$ uncertainty (IERS)") # RNN prediction of LOD)

ymin, ymax = -2.0, 1.0
ax.set_ylim(ymin, ymax)

ax.fill_between(MCM['time_memo'], ymin, ymax, 
            where=(MCM['time_memo']>=fS) & (MCM['time_memo']<=fE), 
            color='yellow', alpha=0.5, label=f'Hindcast period ({fS:.2f} - {fE:.2f})')
ax.fill_between(MCM['time_memo'], ymin, ymax, 
            where=(MCM['time_memo']>=TS-0.2502) & (MCM['time_memo']<=TE-0.2502), 
            color='orange', alpha=0.5, label=f'2015 Pulse ({TS-0.25:.2f} - {TE-0.25:.2f})')

ax.plot([2000, 2030], [0, 0], 'k--', linewidth=2.0)
ax.set_xlim(2004, 2027)

ax.set_xlabel('Date (year)', fontsize=f_large)
ax.set_ylabel("1st Derivative of LOD  [ms/yr]", fontsize=f_large)
ax.set_title(r"SA Energy  (nT/yr$^2$)$^2$   (Trained with Gauss coefs. + LOD)" + 
        f"\n Derivative d={diff} | Seed s=11101 | Drec=34" + 
        f"\n Error/Misfit time: {TS-0.2502:.4f} ≦ t ≦ {TE-0.2502:.4f} \n", 
        fontsize=f_large)
ax.legend(fontsize=f_large, loc='lower left')
plt.tight_layout()
plt.show()
# Out:
#         YEAR  avg_lod  std_lod
# 0 2005.12390  0.29403  2.21533
# 1 2005.37370  0.06493  2.29257
# 2 2005.62390  0.09109  2.19548
# 3 2005.87410  0.02917  2.20340
# 4 2006.12420  0.17366  2.34486

# %%
## Hidden layer states

fig, ax = plot_ht(MCM["ht_memo"], MCM['time_memo'], color="blue", fontsize=f_medium)

fig, ax = plot_ht(LOD["ht_memo"], LOD['time_memo'], color="red", fontsize=f_medium, fig_ax=(fig, ax))

fig, ax = plot_ht(LDT["ht_memo"], LDT['time_memo'], color="purple", fontsize=f_medium, fig_ax=(fig, ax))

ymin, ymax = ax.get_ylim()
ax.set_ylim(ymin, ymax)

ax.fill_between(MCM['time_memo'], ymin, ymax, 
            where=(MCM['time_memo']>=fS) & (MCM['time_memo']<=fE), 
            color='yellow', alpha=0.5, label=f'Hindcast period ({fS:.2f} - {fE:.2f})')
ax.fill_between(MCM['time_memo'], ymin, ymax, 
            where=(MCM['time_memo']>=TS-0.2502) & (MCM['time_memo']<=TE-0.2502), 
            color='orange', alpha=0.5, label=f'2015 Pulse ({TS-0.25:.2f} - {TE-0.25:.2f})')
plt.show()
